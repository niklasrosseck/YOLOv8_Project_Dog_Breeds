# %%
from PIL import Image, ImageOps
import os

# %%
def preprocess_image_resize(input_path, output_path, target_size=(640, 640), quality=85):
    """
    Preprocess an image by resizing and compressing to a target size and quality.
    
    Args:
        input_path (str): Path to the input image.
        output_path (str): Path to save the processed image.
        target_size (tuple): Target dimensions (width, height).
        quality (int): JPEG quality (lower values mean higher compression).
    """
    with Image.open(input_path) as img:
        img = ImageOps.exif_transpose(img)  # Auto-orient based on EXIF
        img = img.convert("RGB")           
        img = img.resize(target_size, Image.Resampling.LANCZOS)
        img.save(output_path, format='JPEG', quality=quality)

# %%
def batch_preprocess_resize(input_folder, output_folder, target_size=(640, 640), quality=85):
    os.makedirs(output_folder, exist_ok=True)
    for filename in os.listdir(input_folder):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)
        try:
            preprocess_image_resize(input_path, output_path, target_size, quality)
            print(f"Processed: {filename}")
        except Exception as e:
            print(f"Error processing {filename}: {e}")

# %%
batch_preprocess_resize("Husky", "Husky_Preprocessed")
# Out:
# Processed: husky_005b52a4.jpg
# Processed: husky_00b546fd.jpg
# Processed: husky_0161242f.jpg
# Processed: husky_054f9e74.jpg
# Processed: husky_06fc4251.jpg
# Processed: husky_084c5b47.jpg
# Processed: husky_087f9029.jpg
# Processed: husky_0b3a88f1.jpg
# Processed: husky_0bbfabca.jpg
# Processed: husky_0c3d3852.jpg
# Processed: husky_0c44dc11.jpg
# Processed: husky_0e4bb2fe.jpg
# Processed: husky_0eb38d47.jpg
# Processed: husky_106af039.jpg
# Processed: husky_10ff3383.jpg
# Processed: husky_12dd8a66.jpg
# Processed: husky_1470eab8.jpg
# Processed: husky_16a4e2b6.jpg
# Processed: husky_1bcbaaae.jpg
# Processed: husky_2116e05f.jpg
# Processed: husky_226f2cbd.jpg
# Processed: husky_23599186.jpg
# Processed: husky_2654bd6e.jpg
# Processed: husky_274ab04f.jpg
# Processed: husky_27eb4078.jpg
# Processed: husky_2ca024cb.jpg
# Processed: husky_2d1d190c.jpg
# Processed: husky_30e5c6a7.jpg
# Processed: husky_31896474.jpg
# Processed: husky_32c92cb5.jpg
# Processed: husky_336771fd.jpg
# Processed: husky_33974936.jpg
# Processed: husky_348c5e51.jpg
# Processed: husky_3d101cd0.jpg
# Processed: husky_4334c8e3.jpg
# Processed: husky_44ef67f8.jpg
# Processed: husky_46f31367.jpg
# Processed: husky_47d16299.jpg
# Processed: husky_4ca954d6.jpg
# Processed: husky_507b0fb7.jpg
# Processed: husky_50de2d70.jpg
# Processed: husky_5153cfbf.jpg
# Processed: husky_52c6704b.jpg
# Processed: husky_53b751ac.jpg
# Processed: husky_55d3c15d.jpg
# Processed: husky_565e42e3.jpg
# Processed: husky_56d371a3.jpg
# Processed: husky_57b644cf.jpg
# Processed: husky_5839fa6f.jpg
# Processed: husky_586b712e.jpg
# Processed: husky_59dec29b.jpg
# Processed: husky_5a3dab90.jpg
# Processed: husky_5e8fe48d.jpg
# Processed: husky_5fa0723a.jpg
# Processed: husky_60c260ef.jpg
# Processed: husky_61da3d0f.jpg
# Processed: husky_6332f552.jpg
# Processed: husky_6481fad2.jpg
# Processed: husky_673c6ecc.jpg
# Processed: husky_677d2c9a.jpg
# Processed: husky_67c5a186.jpg
# Processed: husky_689d1095.jpg
# Processed: husky_6b2f9f27.jpg
# Processed: husky_6b8258d6.jpg
# Processed: husky_6ec1dfe5.jpg
# Processed: husky_707f3a12.jpg
# Processed: husky_72152047.jpg
# Processed: husky_729399b9.jpg
# Processed: husky_73551c10.jpg
# Processed: husky_741d76dd.jpg
# Processed: husky_7514ac01.jpg
# Processed: husky_7687b1f9.jpg
# Processed: husky_7b1a9b7b.jpg
# Processed: husky_7dc77aed.jpg
# Processed: husky_7e117f90.jpg
# Processed: husky_7e526fe5.jpg
# Processed: husky_81d8a110.jpg
# Processed: husky_830c3f40.jpg
# Processed: husky_843cd354.jpg
# Processed: husky_84a47259.jpg
# Processed: husky_870a4829.jpg
# Processed: husky_8b61be12.jpg
# Processed: husky_8bbd8579.jpg
# Processed: husky_8dd219fd.jpg
# Processed: husky_8f80d79f.jpg
# Processed: husky_908430a3.jpg
# Processed: husky_9183e769.jpg
# Processed: husky_973a3a2f.jpg
# Processed: husky_9947fc8d.jpg
# Processed: husky_995124c4.jpg
# Processed: husky_99874b70.jpg
# Processed: husky_9cb10c12.jpg
# Processed: husky_a1bd0880.jpg
# Processed: husky_a4c8a80c.jpg
# Processed: husky_a966e4d1.jpg
# Processed: husky_a9e4088d.jpg
# Processed: husky_abfc59f2.jpg
# Processed: husky_af4216b7.jpg
# Processed: husky_af96c5e9.jpg
# Processed: husky_b0739142.jpg
# Processed: husky_b16612ef.jpg
# Processed: husky_b2a3225c.jpg
# Processed: husky_b38862b9.jpg
# Processed: husky_b59ea6d3.jpg
# Processed: husky_b5f3c3d7.jpg
# Processed: husky_b75457c3.jpg
# Processed: husky_ba0af289.jpg
# Processed: husky_be027aeb.jpg
# Processed: husky_c0c5af89.jpg
# Processed: husky_c14cad4d.jpg
# Processed: husky_c61f64e7.jpg
# Processed: husky_c6a3ff83.jpg
# Processed: husky_c908f751.jpg
# Processed: husky_c9330fbf.jpg
# Processed: husky_c9d0349a.jpg
# Processed: husky_cb6da7c5.jpg
# Processed: husky_cb8b2376.jpg
# Processed: husky_cd2c472e.jpg
# Processed: husky_cf22f5f6.jpg
# Processed: husky_cff2d4b0.jpg
# Processed: husky_d25a6533.jpg
# Processed: husky_d5b43e12.jpg
# Processed: husky_d62f63d5.jpg
# Processed: husky_d68ea96a.jpg
# Processed: husky_d6b19776.jpg
# Processed: husky_d6e6c570.jpg
# Processed: husky_d952185a.jpg
# Processed: husky_dad61510.jpg
# Processed: husky_dce0718e.jpg
# Processed: husky_dce80bbb.jpg
# Processed: husky_dd79d2b2.jpg
# Processed: husky_dec5c39f.jpg
# Processed: husky_e0de5e74.jpg
# Processed: husky_e40df0fc.jpg
# Processed: husky_e48589ff.jpg
# Processed: husky_e6bde430.jpg
# Processed: husky_e7289ea5.jpg
# Processed: husky_e9296268.jpg
# Processed: husky_e99e2147.jpg
# Processed: husky_eb93950b.jpg
# Processed: husky_eb9498e2.jpg
# Processed: husky_ebbd6ea7.jpg
# Processed: husky_ed71c571.jpg
# Processed: husky_edfba216.jpg
# Processed: husky_ee347765.jpg
# Processed: husky_ef3a9864.jpg
# Processed: husky_f3681272.jpg
# Processed: husky_f4ab3aad.jpg
# Processed: husky_f5b6c353.jpg
# Processed: husky_f6132cd5.jpg
# Processed: husky_f7ccd763.jpg
# Processed: husky_f8547241.jpg
# Processed: husky_f8d4a085.jpg
# Processed: husky_fa1be7e9.jpg
# Processed: husky_fc20b345.jpg
# Processed: husky_fc76f1ee.jpg
# Processed: husky_fe64a9c2.jpg
# Processed: husky_fee3229c.jpg
# Processed: husky_ff9cec8e.jpg
